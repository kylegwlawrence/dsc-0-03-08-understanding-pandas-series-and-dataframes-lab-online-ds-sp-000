# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
#Your code here
df.columns = map(str.lower, df.columns)
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %% [markdown]
# # Change the Index to be the Line Names

# %%
#Your code here
df.set_index('linename')
# Out:
#             c/a  unit       scp        station division        date      time  \
# linename
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  16:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  20:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  16:00:00
# ...

# %% [markdown]
# # Painstakingly change the index back

# %%
# Your code here
df.reset_index(drop = True)
# Out:
#           c/a  unit       scp        station linename division        date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# ...

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
# use the string accessor to get length of each string, otherwise it will return length of entire column
df['num_lines'] = df['linename'].str.len()

#sort in place
df.sort_values(by = ['num_lines'], ascending = False, inplace = True)
df.head()
# Out:
#          c/a  unit       scp         station      linename division  \
# 132274  R151  R033  00-00-00  TIMES SQ-42 ST  1237ACENQRSW      IRT
# 2698    A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2699    A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2653    A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2687    A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#              date      time     desc  entries    exits  num_lines
# 132274 2018-08-27  08:00:00  REGULAR  1417716  3259570         12
# 2698   2018-08-31  12:00:00  REGULAR  2840895  3316295         12
# 2699   2018-08-31  16:00:00  REGULAR  2841591  3316775         12
# 2653   2018-08-31  08:00:00  REGULAR  8094536  9796082         12
# 2687   2018-08-29  20:00:00  REGULAR  2837390  3312091         12

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.lower().strip()
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
list(df.columns)
# Out:
# ['c/a',
#  'unit',
#  'scp',
#  'station',
#  'linename',
#  'division',
#  'date',
#  'time',
#  'desc',
#  'entries',
#  'exits']

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#create new column to calculate num entries per day. current entries column is a cumulative amount

#convert date to datetime object
df.date = pd.to_datetime(df.date, format = '%m/%d/%Y')

#sort by ascending date
df.sort_values(by = ['station','scp','date', 'time'], ascending = True, inplace = True)

#day names
df['day_name'] = df.date.dt.day_name()

#grouped data
grouped = df[['entries','exits','day_name']].groupby('day_name').sum()

#plot
grouped.plot(kind = 'bar')
plt.ylabel("volume (not actually true)")
plt.title('Subway traffic by weekday')
plt.plot()
# Out:
# []

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Your code here
grouped.sort_values(by = 'entries')
#more traffic during the weekday than weekend, generally
# Out:
#                  entries         exits
# day_name
# Friday     1110224700078  906799065337
# Monday     1114237052454  911938153513
# Saturday   1115661545514  909142081474
# Thursday   1122723988662  920691927110
# Wednesday  1123655222441  920630864687
# Tuesday    1143313287046  942230721477
# Sunday     1192306179082  959223750461

# %% [markdown]
# # Drop a couple of columns

# %%
# Your code here
df.drop()
